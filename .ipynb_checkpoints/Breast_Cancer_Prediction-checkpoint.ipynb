# %%
# importación de las librerias que serán utilizadas para el análisis y preparación de los datos
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import RobustScaler
from sklearn.pipeline import Pipeline

# %%
#Lectura del dataset 
df = pd.read_csv('breast-cancer.csv')

# %%
#Visualización inicial del conjunto de datos
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0            0.11840           0.27760         0.30010              0.14710
# 1            0.08474           0.07864         0.08690              0.07017
# 2            0.10960           0.15990         0.19740              0.12790
# 3            0.14250           0.28390         0.24140              0.10520
# 4            0.10030           0.13280         0.19800              0.10430
# ..               ...               ...             ...                  ...
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
#      ...  radius_worst  texture_worst  perimeter_worst  area_worst  \
# 0    ...        25.380          17.33           184.60      2019.0
# 1    ...        24.990          23.41           158.80      1956.0
# 2    ...        23.570          25.53           152.50      1709.0
# 3    ...        14.910          26.50            98.87       567.7
# 4    ...        22.540          16.67           152.20      1575.0
# ..   ...           ...            ...              ...         ...
# 564  ...        25.450          26.40           166.10      2027.0
# 565  ...        23.690          38.25           155.00      1731.0
# 566  ...        18.980          34.12           126.70      1124.0
# 567  ...        25.740          39.42           184.60      1821.0
# 568  ...         9.456          30.37            59.16       268.6
#
#      smoothness_worst  compactness_worst  concavity_worst  \
# 0             0.16220            0.66560           0.7119
# 1             0.12380            0.18660           0.2416
# 2             0.14440            0.42450           0.4504
# 3             0.20980            0.86630           0.6869
# 4             0.13740            0.20500           0.4000
# ..                ...                ...              ...
# 564           0.14100            0.21130           0.4107
# 565           0.11660            0.19220           0.3215
# 566           0.11390            0.30940           0.3403
# 567           0.16500            0.86810           0.9387
# 568           0.08996            0.06444           0.0000
#
#      concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                  0.2654          0.4601                  0.11890
# 1                  0.1860          0.2750                  0.08902
# 2                  0.2430          0.3613                  0.08758
# 3                  0.2575          0.6638                  0.17300
# 4                  0.1625          0.2364                  0.07678
# ..                    ...             ...                      ...
# 564                0.2216          0.2060                  0.07115
# 565                0.1628          0.2572                  0.06637
# 566                0.1418          0.2218                  0.07820
# 567                0.2650          0.4087                  0.12400
# 568                0.0000          0.2871                  0.07039
#
# [569 rows x 32 columns]

# %% [markdown]
# # Evaluación de los datos

# %%
#Visualizamos la informacion básica del conjunto de datos
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
#  14  perimeter_se             569 non-null    float64
#  15  area_se                  569 non-null    float64
#  16  smoothness_se            569 non-null    float64
#  17  compactness_se           569 non-null    float64
#  18  concavity_se             569 non-null    float64
#  19  concave points_se        569 non-null    float64
#  20  symmetry_se              569 non-null    float64
#  21  fractal_dimension_se     569 non-null    float64
#  22  radius_worst             569 non-null    float64
#  23  texture_worst            569 non-null    float64
#  24  perimeter_worst          569 non-null    float64
#  25  area_worst               569 non-null    float64
#  26  smoothness_worst         569 non-null    float64
#  27  compactness_worst        569 non-null    float64
#  28  concavity_worst          569 non-null    float64
#  29  concave points_worst     569 non-null    float64
#  30  symmetry_worst           569 non-null    float64
#  31  fractal_dimension_worst  569 non-null    float64
# dtypes: float64(30), int64(1), object(1)
# memory usage: 142.4+ KB

# %%
#Visualización de la información estadística del conjunto de datos
df.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# 25%           0.086370          0.064920        0.029560             0.020310
# 50%           0.095870          0.092630        0.061540             0.033500
# 75%           0.105300          0.130400        0.130700             0.074000
# max           0.163400          0.345400        0.426800             0.201200
#
#        symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# count     569.000000  ...    569.000000     569.000000       569.000000
# mean        0.181162  ...     16.269190      25.677223       107.261213
# std         0.027414  ...      4.833242       6.146258        33.602542
# min         0.106000  ...      7.930000      12.020000        50.410000
# 25%         0.161900  ...     13.010000      21.080000        84.110000
# 50%         0.179200  ...     14.970000      25.410000        97.660000
# 75%         0.195700  ...     18.790000      29.720000       125.400000
# max         0.304000  ...     36.040000      49.540000       251.200000
#
#         area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# count   569.000000        569.000000         569.000000       569.000000
# mean    880.583128          0.132369           0.254265         0.272188
# std     569.356993          0.022832           0.157336         0.208624
# min     185.200000          0.071170           0.027290         0.000000
# 25%     515.300000          0.116600           0.147200         0.114500
# 50%     686.500000          0.131300           0.211900         0.226700
# 75%    1084.000000          0.146000           0.339100         0.382900
# max    4254.000000          0.222600           1.058000         1.252000
#
#        concave points_worst  symmetry_worst  fractal_dimension_worst
# count            569.000000      569.000000               569.000000
# mean               0.114606        0.290076                 0.083946
# std                0.065732        0.061867                 0.018061
# min                0.000000        0.156500                 0.055040
# 25%                0.064930        0.250400                 0.071460
# 50%                0.099930        0.282200                 0.080040
# 75%                0.161400        0.317900                 0.092080
# max                0.291000        0.663800                 0.207500
#
# [8 rows x 31 columns]

# %%
# Copiamos el conjunto de datos y transformamos la variable de salida a numérica para calcular correlaciones
df_new = df.copy()
df_new['diagnosis'] = df_new['diagnosis'].factorize()[0]

# %%
df_new
# Out:
#            id  diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 0      842302          0        17.99         10.38          122.80
# 1      842517          0        20.57         17.77          132.90
# 2    84300903          0        19.69         21.25          130.00
# 3    84348301          0        11.42         20.38           77.58
# 4    84358402          0        20.29         14.34          135.10
# ..        ...        ...          ...           ...             ...
# 564    926424          0        21.56         22.39          142.00
# 565    926682          0        20.13         28.25          131.20
# 566    926954          0        16.60         28.08          108.30
# 567    927241          0        20.60         29.33          140.10
# 568     92751          1         7.76         24.54           47.92
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 0       1001.0          0.11840           0.27760         0.30010
# 1       1326.0          0.08474           0.07864         0.08690
# 2       1203.0          0.10960           0.15990         0.19740
# 3        386.1          0.14250           0.28390         0.24140
# 4       1297.0          0.10030           0.13280         0.19800
# ..         ...              ...               ...             ...
# 564     1479.0          0.11100           0.11590         0.24390
# 565     1261.0          0.09780           0.10340         0.14400
# 566      858.1          0.08455           0.10230         0.09251
# 567     1265.0          0.11780           0.27700         0.35140
# 568      181.0          0.05263           0.04362         0.00000
#
#      concave points_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0                0.14710  ...        25.380          17.33           184.60
# 1                0.07017  ...        24.990          23.41           158.80
# 2                0.12790  ...        23.570          25.53           152.50
# 3                0.10520  ...        14.910          26.50            98.87
# 4                0.10430  ...        22.540          16.67           152.20
# ..                   ...  ...           ...            ...              ...
# 564              0.13890  ...        25.450          26.40           166.10
# 565              0.09791  ...        23.690          38.25           155.00
# 566              0.05302  ...        18.980          34.12           126.70
# 567              0.15200  ...        25.740          39.42           184.60
# 568              0.00000  ...         9.456          30.37            59.16
#
#      area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0        2019.0           0.16220            0.66560           0.7119
# 1        1956.0           0.12380            0.18660           0.2416
# 2        1709.0           0.14440            0.42450           0.4504
# 3         567.7           0.20980            0.86630           0.6869
# 4        1575.0           0.13740            0.20500           0.4000
# ..          ...               ...                ...              ...
# 564      2027.0           0.14100            0.21130           0.4107
# 565      1731.0           0.11660            0.19220           0.3215
# 566      1124.0           0.11390            0.30940           0.3403
# 567      1821.0           0.16500            0.86810           0.9387
# 568       268.6           0.08996            0.06444           0.0000
#
#      concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                  0.2654          0.4601                  0.11890
# 1                  0.1860          0.2750                  0.08902
# 2                  0.2430          0.3613                  0.08758
# 3                  0.2575          0.6638                  0.17300
# 4                  0.1625          0.2364                  0.07678
# ..                    ...             ...                      ...
# 564                0.2216          0.2060                  0.07115
# 565                0.1628          0.2572                  0.06637
# 566                0.1418          0.2218                  0.07820
# 567                0.2650          0.4087                  0.12400
# 568                0.0000          0.2871                  0.07039
#
# [569 rows x 32 columns]

# %%
#Validación de la cantidad de ejemplos que posee el dataset segun la variable de salida.
df_new["diagnosis"].value_counts()
# Out:
# 1    357
# 0    212
# Name: diagnosis, dtype: int64

# %%
# Validación de la correlación entre las variables de entrada con relación a la variable de salida.
corr_matrix = df_new.corr()
corr_matrix["diagnosis"].sort_values(ascending=False)
# Out:
# diagnosis                  1.000000
# smoothness_se              0.067016
# fractal_dimension_mean     0.012838
# texture_se                 0.008303
# symmetry_se                0.006522
# id                        -0.039769
# fractal_dimension_se      -0.077972
# concavity_se              -0.253730
# compactness_se            -0.292999
# fractal_dimension_worst   -0.323872
# symmetry_mean             -0.330499
# smoothness_mean           -0.358560
# concave points_se         -0.408042
# texture_mean              -0.415185
# symmetry_worst            -0.416294
# smoothness_worst          -0.421465
# texture_worst             -0.456903
# area_se                   -0.548236
# perimeter_se              -0.556141
# radius_se                 -0.567134
# compactness_worst         -0.590998
# compactness_mean          -0.596534
# concavity_worst           -0.659610
# concavity_mean            -0.696360
# area_mean                 -0.708984
# radius_mean               -0.730029
# area_worst                -0.733825
# perimeter_mean            -0.742636
# radius_worst              -0.776454
# concave points_mean       -0.776614
# perimeter_worst           -0.782914
# concave points_worst      -0.793566
# Name: diagnosis, dtype: float64

# %%
#Validación si hay algún valor nulo en el conjunto de datos.
df.isna().any()
# Out:
# id                         False
# diagnosis                  False
# radius_mean                False
# texture_mean               False
# perimeter_mean             False
# area_mean                  False
# smoothness_mean            False
# compactness_mean           False
# concavity_mean             False
# concave points_mean        False
# symmetry_mean              False
# fractal_dimension_mean     False
# radius_se                  False
# texture_se                 False
# perimeter_se               False
# area_se                    False
# smoothness_se              False
# compactness_se             False
# concavity_se               False
# concave points_se          False
# symmetry_se                False
# fractal_dimension_se       False
# radius_worst               False
# texture_worst              False
# perimeter_worst            False
# area_worst                 False
# smoothness_worst           False
# compactness_worst          False
# concavity_worst            False
# concave points_worst       False
# symmetry_worst             False
# fractal_dimension_worst    False
# dtype: bool

# %%
#Eliminación de datos que son irrelevantes y que podrian afectar el resultado.
df_new2 = df_new.drop(['id'], axis=1)

# %%
#Vizualición de los cambios aplicados
df_new2
# Out:
#      diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0            0        17.99         10.38          122.80     1001.0
# 1            0        20.57         17.77          132.90     1326.0
# 2            0        19.69         21.25          130.00     1203.0
# 3            0        11.42         20.38           77.58      386.1
# 4            0        20.29         14.34          135.10     1297.0
# ..         ...          ...           ...             ...        ...
# 564          0        21.56         22.39          142.00     1479.0
# 565          0        20.13         28.25          131.20     1261.0
# 566          0        16.60         28.08          108.30      858.1
# 567          0        20.60         29.33          140.10     1265.0
# 568          1         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0            0.11840           0.27760         0.30010              0.14710
# 1            0.08474           0.07864         0.08690              0.07017
# 2            0.10960           0.15990         0.19740              0.12790
# 3            0.14250           0.28390         0.24140              0.10520
# 4            0.10030           0.13280         0.19800              0.10430
# ..               ...               ...             ...                  ...
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
#      symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0           0.2419  ...        25.380          17.33           184.60
# 1           0.1812  ...        24.990          23.41           158.80
# 2           0.2069  ...        23.570          25.53           152.50
# 3           0.2597  ...        14.910          26.50            98.87
# 4           0.1809  ...        22.540          16.67           152.20
# ..             ...  ...           ...            ...              ...
# 564         0.1726  ...        25.450          26.40           166.10
# 565         0.1752  ...        23.690          38.25           155.00
# 566         0.1590  ...        18.980          34.12           126.70
# 567         0.2397  ...        25.740          39.42           184.60
# 568         0.1587  ...         9.456          30.37            59.16
#
#      area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0        2019.0           0.16220            0.66560           0.7119
# 1        1956.0           0.12380            0.18660           0.2416
# 2        1709.0           0.14440            0.42450           0.4504
# 3         567.7           0.20980            0.86630           0.6869
# 4        1575.0           0.13740            0.20500           0.4000
# ..          ...               ...                ...              ...
# 564      2027.0           0.14100            0.21130           0.4107
# 565      1731.0           0.11660            0.19220           0.3215
# 566      1124.0           0.11390            0.30940           0.3403
# 567      1821.0           0.16500            0.86810           0.9387
# 568       268.6           0.08996            0.06444           0.0000
#
#      concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                  0.2654          0.4601                  0.11890
# 1                  0.1860          0.2750                  0.08902
# 2                  0.2430          0.3613                  0.08758
# 3                  0.2575          0.6638                  0.17300
# 4                  0.1625          0.2364                  0.07678
# ..                    ...             ...                      ...
# 564                0.2216          0.2060                  0.07115
# 565                0.1628          0.2572                  0.06637
# 566                0.1418          0.2218                  0.07820
# 567                0.2650          0.4087                  0.12400
# 568                0.0000          0.2871                  0.07039
#
# [569 rows x 31 columns]

# %%
# Representación gráfica de la distribución de los atributos
df_new2.hist(bins=50, figsize=(20,15))
plt.show()

# %%
#Creación de una gráfica para representar el porcentaje de los casos que posee el dataset
Gender = df['diagnosis'].value_counts()

fig, ax = plt.subplots(figsize =(8, 6))
_, _, autotexts = ax.pie(x=Gender, labels=Gender.index, autopct="%.2f%%", radius=1.2,
                         colors=sns.color_palette("YlOrBr_r"), explode=None, textprops=dict(fontsize=13))

ax.set_title('Porcentaje de casos detectados', y=1.1, weight='bold', fontsize=14)
ax.legend(labels=['Benignos', 'Malignos'], fontsize=14)

for autotext in autotexts:
    autotext.set_color('white')
    autotext.set_weight('bold')

# %% [markdown]
# ## Escalado de los datos

# %%
# Conjunto de datos general
X_df = df_new2.drop("diagnosis", axis=1)
y_df = df_new2["diagnosis"].copy()

# %%
#Escalado de los datos
scaler = RobustScaler()
X_scaled = scaler.fit_transform(X_df)

# %%
# Transformación a un DataFrame de Pandas
X_scaled = pd.DataFrame(X_scaled, columns=X_df.columns, index=X_df.index)

# %%
#Visualización de los cambios
X_scaled
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0       1.132353     -1.502664        1.263740   1.241446         1.190174
# 1       1.764706     -0.190053        1.612859   2.138245        -0.587956
# 2       1.549020      0.428064        1.512617   1.798841         0.725304
# 3      -0.477941      0.273535       -0.299343  -0.455298         2.463286
# 4       1.696078     -0.799290        1.688904   2.058223         0.234020
# ..           ...           ...             ...        ...              ...
# 564     2.007353      0.630551        1.927411   2.560430         0.799260
# 565     1.656863      1.671403        1.554096   1.958885         0.101955
# 566     0.791667      1.641208        0.762530   0.847130        -0.597993
# 567     1.772059      1.863233        1.861735   1.969923         1.158479
# 568    -1.375000      1.012433       -1.324577  -1.021247        -2.284205
#
#      compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0            2.824832        2.358711             2.115850       1.855030
# 1           -0.213653        0.250742             0.682995       0.059172
# 2            1.027337        1.343287             1.758242       0.819527
# 3            2.921045        1.778327             1.335444       2.381657
# 4            0.613470        1.349219             1.318681       0.050296
# ..                ...             ...                  ...            ...
# 564          0.355376        1.803045             1.963122      -0.195266
# 565          0.164478        0.815306             1.199665      -0.118343
# 566          0.147679        0.306209             0.363569      -0.597633
# 567          2.815669        2.865928             2.207115       1.789941
# 568         -0.748473       -0.608464            -0.623952      -0.606509
#
#      fractal_dimension_mean  ...  radius_worst  texture_worst  \
# 0                  2.039192  ...      1.801038      -0.935185
# 1                 -0.578385  ...      1.733564      -0.231481
# 2                 -0.184086  ...      1.487889       0.013889
# 3                  4.263658  ...     -0.010381       0.126157
# 4                 -0.321853  ...      1.309689      -1.011574
# ..                      ...  ...           ...            ...
# 564               -0.630641  ...      1.813149       0.114583
# 565               -0.737530  ...      1.508651       1.486111
# 566               -0.600950  ...      0.693772       1.008102
# 567                1.023753  ...      1.863322       1.621528
# 568               -0.320665  ...     -0.953979       0.574074
#
#      perimeter_worst  area_worst  smoothness_worst  compactness_worst  \
# 0           2.105595    2.343063          1.051020           2.364252
# 1           1.480746    2.232284         -0.255102          -0.131839
# 2           1.328167    1.797960          0.445578           1.107869
# 3           0.029305   -0.208897          2.670068           3.410109
# 4           1.320901    1.562335          0.207483          -0.035956
# ..               ...         ...               ...                ...
# 564         1.657544    2.357130          0.329932          -0.003127
# 565         1.388714    1.836645         -0.500000          -0.102658
# 566         0.703318    0.769298         -0.591837           0.508077
# 567         2.105595    1.994901          1.146259           3.419489
# 568        -0.932429   -0.734834         -1.406122          -0.768421
#
#      concavity_worst  concave points_worst  symmetry_worst  \
# 0           1.807750              1.715248        2.635556
# 1           0.055514              0.892194       -0.106667
# 2           0.833458              1.483052        1.171852
# 3           1.714605              1.633358        5.653333
# 4           0.645678              0.648595       -0.678519
# ..               ...                   ...             ...
# 564         0.685544              1.261221       -1.128889
# 565         0.353204              0.651705       -0.370370
# 566         0.423249              0.434021       -0.894815
# 567         2.652757              1.711102        1.874074
# 568        -0.844635             -1.035866        0.072593
#
#      fractal_dimension_worst
# 0                   1.884578
# 1                   0.435500
# 2                   0.365664
# 3                   4.508244
# 4                  -0.158099
# ..                       ...
# 564                -0.431135
# 565                -0.662949
# 566                -0.089234
# 567                 2.131911
# 568                -0.467992
#
# [569 rows x 30 columns]

# %% [markdown]
# ## Balanceo del dataset

# %% [markdown]
# Según el análisis realizado, el conjunto de datos posee un desbalance con 357 casos benignos y 212 casos malignos, al entrenar los diferentes algoritmos generaria una matriz de confusión desbalanceda, por lo que se hara uso de la combinación de las técnicas de sobremuestreo y submuestreo para equilibrar la cantidad de datos.

# %% [markdown]
# ## Sobremuestreo + Submuestreo

# %%
no = y_df.sum()
si = y_df.shape[0]- no
print('Casos benignos:',no,'Casos malignos:', si)
# Out:
# Casos benignos: 357 Casos malignos: 212

# %%
#Importamos los paquetes
from imblearn.combine import SMOTETomek

#Inicialización del método combinado
#SMOTE Tomek
smoteT = SMOTETomek()

# %%
#Sobremuestreo con Smote seguido de un submuestreo con Uniones de Tomek
X_smoteT, y_smoteT = smoteT.fit_resample(X_scaled, y_df)
no_smoteT = y_smoteT.sum()
si_smoteT = y_smoteT.shape[0]- no_smoteT
print('Casos benignos:',no_smoteT ,'Casos malignos:', si_smoteT)
X_smoteT
# Out:
# Casos benignos: 353 Casos malignos: 353
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0       1.132353     -1.502664        1.263740   1.241446         1.190174
# 1       1.764706     -0.190053        1.612859   2.138245        -0.587956
# 2       1.549020      0.428064        1.512617   1.798841         0.725304
# 3      -0.477941      0.273535       -0.299343  -0.455298         2.463286
# 4       1.696078     -0.799290        1.688904   2.058223         0.234020
# ..           ...           ...             ...        ...              ...
# 701     0.164077     -0.351513        0.192309   0.147531         0.168577
# 702     1.103603      1.177948        1.149260   1.315005         0.351223
# 703     1.253174     -0.085371        1.206167   1.446273         0.191981
# 704     0.210466      1.376828        0.290423   0.219022         0.903411
# 705     1.463134      0.492025        1.423388   1.670805         0.557606
#
#      compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0            2.824832        2.358711             2.115850       1.855030
# 1           -0.213653        0.250742             0.682995       0.059172
# 2            1.027337        1.343287             1.758242       0.819527
# 3            2.921045        1.778327             1.335444       2.381657
# 4            0.613470        1.349219             1.318681       0.050296
# ..                ...             ...                  ...            ...
# 701          0.483834        0.123044             0.265753      -0.353504
# 702          1.169454        1.454418             1.355102      -0.548137
# 703          0.201730        0.725330             1.011377       0.949564
# 704          1.077943        1.022142             0.730570       1.414887
# 705          0.799470        1.503323             1.447899       0.175537
#
#      fractal_dimension_mean  ...  radius_worst  texture_worst  \
# 0                  2.039192  ...      1.801038      -0.935185
# 1                 -0.578385  ...      1.733564      -0.231481
# 2                 -0.184086  ...      1.487889       0.013889
# 3                  4.263658  ...     -0.010381       0.126157
# 4                 -0.321853  ...      1.309689      -1.011574
# ..                      ...  ...           ...            ...
# 701                0.441469  ...      0.311244      -0.392366
# 702                0.220013  ...      1.477472       0.889213
# 703               -0.130741  ...      1.363663       0.225812
# 704                1.134468  ...      0.359615       1.209412
# 705               -0.001597  ...      1.540472       0.805095
#
#      perimeter_worst  area_worst  smoothness_worst  compactness_worst  \
# 0           2.105595    2.343063          1.051020           2.364252
# 1           1.480746    2.232284         -0.255102          -0.131839
# 2           1.328167    1.797960          0.445578           1.107869
# 3           0.029305   -0.208897          2.670068           3.410109
# 4           1.320901    1.562335          0.207483          -0.035956
# ..               ...         ...               ...                ...
# 701         0.319841    0.267097          0.272803           0.721046
# 702         1.505231    1.802354          0.151726           1.042842
# 703         1.302004    1.600675          0.330095          -0.003555
# 704         0.557460    0.375450          1.302798           2.206021
# 705         1.413318    1.842381          1.010583           0.858572
#
#      concavity_worst  concave points_worst  symmetry_worst  \
# 0           1.807750              1.715248        2.635556
# 1           0.055514              0.892194       -0.106667
# 2           0.833458              1.483052        1.171852
# 3           1.714605              1.633358        5.653333
# 4           0.645678              0.648595       -0.678519
# ..               ...                   ...             ...
# 701         0.242055              0.371411       -0.204736
# 702         0.931180              0.792260       -0.792012
# 703         0.336511              0.670024        1.157171
# 704         1.722637              0.788786        1.849423
# 705         1.342671              1.029624        0.653527
#
#      fractal_dimension_worst
# 0                   1.884578
# 1                   0.435500
# 2                   0.365664
# 3                   4.508244
# 4                  -0.158099
# ..                       ...
# 701                 1.072056
# 702                 0.698935
# 703                 0.272011
# 704                 2.535206
# 705                 0.611049
#
# [706 rows x 30 columns]

# %% [markdown]
# ## Entrenar y evaluar utilizando regresión logística

# %%
#División del dataset en conjunto de entramiento y prueba
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(X_smoteT, y_smoteT, test_size = 0.25, random_state=0)

# %%
# Entrenamos un algoritmo basado en regresión logística
from sklearn.linear_model import LogisticRegression

#Creación del modelo
clf = LogisticRegression(random_state =0).fit(X_train, y_train)

# %%
#Prediccion con el conjunto de pruebas
y_pred = clf.predict(X_val)

# %%
#Validación del accuracy
from sklearn.metrics import accuracy_score
print('Accuracy: {:.3f}'.format(accuracy_score(y_val, y_pred)))
# Out:
# Accuracy: 0.983

# %%
#Validación de la matriz de confusión
from sklearn.metrics import confusion_matrix
confusion_matrix(y_val, y_pred)
# Out:
# array([[84,  3],
#        [ 0, 90]], dtype=int64)

# %%
#Representación gráfica de los resultados de la matriz de confusión con el conjunto de pruebas
from sklearn.metrics import plot_confusion_matrix

plot_confusion_matrix(clf, X_val, y_val, values_format='3g')
# Out:
# C:\Users\eliza\AppData\Roaming\Python\Python38\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
#Descripción de los resultados de diferentes métricas de medición sobre el modelo entrenado y probado
from sklearn.metrics import confusion_matrix,classification_report,plot_confusion_matrix
print(confusion_matrix(y_val, y_pred))
print(classification_report(y_val, y_pred))
# Out:
# [[84  3]
#  [ 0 90]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.98        87
#            1       0.97      1.00      0.98        90
#
#     accuracy                           0.98       177
#    macro avg       0.98      0.98      0.98       177
# weighted avg       0.98      0.98      0.98       177

# %% [markdown]
# ## Entrenar y evaluar utilizando bosques aleatorios

# %%
#División del dataset en conjunto de entramiento y prueba
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(X_smoteT, y_smoteT, test_size = 0.25, random_state=0)

# %%
# Importación de la librería 
from sklearn.ensemble import RandomForestClassifier

#Creación del modelo
ranforest = RandomForestClassifier()
ranforest.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
#Prediccion con el conjunto de pruebas
y_pred = ranforest.predict(X_val)

# %%
#Validación del accuracy
from sklearn.metrics import accuracy_score
print('Accuracy: {:.3f}'.format(accuracy_score(y_val, y_pred)))
# Out:
# Accuracy: 0.977

# %%
#Validación de la matriz de confusión
from sklearn.metrics import confusion_matrix
confusion_matrix(y_val, y_pred)
# Out:
# array([[85,  2],
#        [ 2, 88]], dtype=int64)

# %%
#Representación gráfica de los resultados de la matriz de confusión con el conjunto de pruebas
from sklearn.metrics import plot_confusion_matrix

plot_confusion_matrix(ranforest, X_val, y_val, values_format='3g')
# Out:
# C:\Users\eliza\AppData\Roaming\Python\Python38\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
#Descripción de los resultados de diferentes métricas de medición sobre el modelo entrenado y probado
from sklearn.metrics import confusion_matrix,classification_report,plot_confusion_matrix
print(confusion_matrix(y_val, y_pred))
print(classification_report(y_val, y_pred))
# Out:
# [[85  2]
#  [ 2 88]]
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98        87
#            1       0.98      0.98      0.98        90
#
#     accuracy                           0.98       177
#    macro avg       0.98      0.98      0.98       177
# weighted avg       0.98      0.98      0.98       177

# %% [markdown]
# ## Entrenar y evaluar utilizando K-Nearest Neighbors

# %%
#División del dataset en conjunto de entramiento y prueba
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(X_smoteT, y_smoteT, test_size = 0.25, random_state=0)

# %%
# Ajustar el clasificador en el Conjunto de Entrenamiento
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors = 5, metric = "minkowski", p = 2)
classifier.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
# Predicción de los resultados con el Conjunto de Testing
y_pred  = classifier.predict(X_val)

# %%
#Validación del accuracy
from sklearn.metrics import accuracy_score
print('Accuracy: {:.3f}'.format(accuracy_score(y_val, y_pred)))
# Out:
# Accuracy: 0.966

# %%
#Validación de la matriz de confusión
from sklearn.metrics import confusion_matrix
confusion_matrix(y_val, y_pred)
# Out:
# array([[84,  3],
#        [ 3, 87]], dtype=int64)

# %%
#Representación gráfica de los resultados de la matriz de confusión con el conjunto de pruebas
from sklearn.metrics import plot_confusion_matrix
plot_confusion_matrix(classifier, X_val, y_val, values_format='3g')
# Out:
# C:\Users\eliza\AppData\Roaming\Python\Python38\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
#Descripción de los resultados de diferentes métricas de medición sobre el modelo entrenado y probado
from sklearn.metrics import confusion_matrix,classification_report,plot_confusion_matrix
print(confusion_matrix(y_val, y_pred))
print(classification_report(y_val, y_pred))
# Out:
# [[84  3]
#  [ 3 87]]
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97        87
#            1       0.97      0.97      0.97        90
#
#     accuracy                           0.97       177
#    macro avg       0.97      0.97      0.97       177
# weighted avg       0.97      0.97      0.97       177

# %% [markdown]
# ## Entrenar y evaluar utilizando Support Vector Machine

# %%
#División del dataset en conjunto de entramiento y prueba
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(X_smoteT, y_smoteT, test_size = 0.25, random_state=0)

# %%
# Ajustar el SVM en el Conjunto de Entrenamiento
from sklearn.svm import SVC
classifier = SVC(kernel = "linear", random_state = 0)
classifier.fit(X_train, y_train)
# Out:
# SVC(kernel='linear', random_state=0)

# %%
# Predicción de los resultados con el Conjunto de Testing
y_pred  = classifier.predict(X_val)

# %%
#Validación del accuracy
from sklearn.metrics import accuracy_score
print('Accuracy: {:.3f}'.format(accuracy_score(y_val, y_pred)))
# Out:
# Accuracy: 0.983

# %%
#Validación de la matriz de confusión
from sklearn.metrics import confusion_matrix
confusion_matrix(y_val, y_pred)
# Out:
# array([[84,  3],
#        [ 0, 90]], dtype=int64)

# %%
#Representación gráfica de los resultados de la matriz de confusión con el conjunto de pruebas
from sklearn.metrics import plot_confusion_matrix
plot_confusion_matrix(classifier, X_val, y_val, values_format='3g')
# Out:
# C:\Users\eliza\AppData\Roaming\Python\Python38\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
#Descripción de los resultados de diferentes métricas de medición sobre el modelo entrenado y probado
from sklearn.metrics import confusion_matrix,classification_report,plot_confusion_matrix
print(confusion_matrix(y_val, y_pred))
print(classification_report(y_val, y_pred))
# Out:
# [[84  3]
#  [ 0 90]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.98        87
#            1       0.97      1.00      0.98        90
#
#     accuracy                           0.98       177
#    macro avg       0.98      0.98      0.98       177
# weighted avg       0.98      0.98      0.98       177

# %% [markdown]
# ## Entrenar y evaluar utilizando Kernel Support Vector Machine

# %%
#División del dataset en conjunto de entramiento y prueba
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(X_smoteT, y_smoteT, test_size = 0.25, random_state=0)

# %%
# Ajustar el clasificador en el Conjunto de Entrenamiento
from sklearn.svm import SVC
classifier = SVC(kernel = "rbf", random_state = 0)
classifier.fit(X_train, y_train)
# Out:
# SVC(random_state=0)

# %%
# Predicción de los resultados con el Conjunto de Testing
y_pred  = classifier.predict(X_val)

# %%
#Validación del accuracy
from sklearn.metrics import accuracy_score
print('Accuracy: {:.3f}'.format(accuracy_score(y_val, y_pred)))
# Out:
# Accuracy: 0.989

# %%
#Validación de la matriz de confusión
from sklearn.metrics import confusion_matrix
confusion_matrix(y_val, y_pred)
# Out:
# array([[85,  2],
#        [ 0, 90]], dtype=int64)

# %%
#Representación gráfica de los resultados de la matriz de confusión con el conjunto de pruebas
from sklearn.metrics import plot_confusion_matrix
plot_confusion_matrix(classifier, X_val, y_val, values_format='3g')
# Out:
# C:\Users\eliza\AppData\Roaming\Python\Python38\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
#Descripción de los resultados de diferentes métricas de medición sobre el modelo entrenado y probado
from sklearn.metrics import confusion_matrix,classification_report,plot_confusion_matrix
print(confusion_matrix(y_val, y_pred))
print(classification_report(y_val, y_pred))
# Out:
# [[85  2]
#  [ 0 90]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99        87
#            1       0.98      1.00      0.99        90
#
#     accuracy                           0.99       177
#    macro avg       0.99      0.99      0.99       177
# weighted avg       0.99      0.99      0.99       177

# %% [markdown]
# ## Entrenar y evaluar utilizando Naive Bayes

# %%
#División del dataset en conjunto de entramiento y prueba
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(X_smoteT, y_smoteT, test_size = 0.25, random_state=0)

# %%
from sklearn.naive_bayes import BernoulliNB

nb_clf = BernoulliNB(alpha=1.0e-10)
nb_clf.fit(X_train, y_train)
# Out:
# BernoulliNB(alpha=1e-10)

# %%
# Predicción de los resultados con el Conjunto de Testing
y_pred  = nb_clf.predict(X_val)

# %%
#Validación del accuracy
from sklearn.metrics import accuracy_score
print('Accuracy: {:.3f}'.format(accuracy_score(y_val, y_pred)))
# Out:
# Accuracy: 0.932

# %%
#Validación de la matriz de confusión
from sklearn.metrics import confusion_matrix
confusion_matrix(y_val, y_pred)
# Out:
# array([[80,  7],
#        [ 5, 85]], dtype=int64)

# %%
#Representación gráfica de los resultados de la matriz de confusión con el conjunto de pruebas
from sklearn.metrics import plot_confusion_matrix
plot_confusion_matrix(nb_clf, X_val, y_val, values_format='3g')
# Out:
# C:\Users\eliza\AppData\Roaming\Python\Python38\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
#Descripción de los resultados de diferentes métricas de medición sobre el modelo entrenado y probado
from sklearn.metrics import confusion_matrix,classification_report,plot_confusion_matrix
print(confusion_matrix(y_val, y_pred))
print(classification_report(y_val, y_pred))
# Out:
# [[80  7]
#  [ 5 85]]
#               precision    recall  f1-score   support
#
#            0       0.94      0.92      0.93        87
#            1       0.92      0.94      0.93        90
#
#     accuracy                           0.93       177
#    macro avg       0.93      0.93      0.93       177
# weighted avg       0.93      0.93      0.93       177

# %% [markdown]
# ## Entrenar y evaluar utilizando árboles de decisión

# %%
#División del dataset en conjunto de entramiento y prueba
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(X_smoteT, y_smoteT, test_size = 0.25, random_state=0)

# %%
# Ajustar el clasificador de Árbol de Decisión en el Conjunto de Entrenamiento
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier(criterion = "entropy", random_state = 0)
classifier.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=0)

# %%
# Predicción de los resultados con el Conjunto de Testing
y_pred  = classifier.predict(X_val)

# %%
#Validación del accuracy
from sklearn.metrics import accuracy_score
print('Accuracy: {:.3f}'.format(accuracy_score(y_val, y_pred)))
# Out:
# Accuracy: 0.977

# %%
#Validación de la matriz de confusión
from sklearn.metrics import confusion_matrix
confusion_matrix(y_val, y_pred)
# Out:
# array([[85,  2],
#        [ 2, 88]], dtype=int64)

# %%
#Representación gráfica de los resultados de la matriz de confusión con el conjunto de pruebas
from sklearn.metrics import plot_confusion_matrix
plot_confusion_matrix(classifier, X_val, y_val, values_format='3g')
# Out:
# C:\Users\eliza\AppData\Roaming\Python\Python38\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
#Descripción de los resultados de diferentes métricas de medición sobre el modelo entrenado y probado
from sklearn.metrics import confusion_matrix,classification_report,plot_confusion_matrix
print(confusion_matrix(y_val, y_pred))
print(classification_report(y_val, y_pred))
# Out:
# [[85  2]
#  [ 2 88]]
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98        87
#            1       0.98      0.98      0.98        90
#
#     accuracy                           0.98       177
#    macro avg       0.98      0.98      0.98       177
# weighted avg       0.98      0.98      0.98       177
